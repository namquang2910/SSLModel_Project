# %%
import random
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, Dataset, random_split
import wfdb
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import neurokit2 as nk
from scipy.signal import resample, medfilt
import pywt
import pickle
import time
import os
import mne
from tqdm import tqdm
from sklearn.preprocessing import MinMaxScaler

# %%
def preprocessing_data(signal, target_rate=100, original_rate=360):
    coeffs = pywt.wavedec(signal, 'db4', level=5) #Wavelet decomposition, reduces noise, enhances key elements
    signal = pywt.waverec(coeffs, 'db4')
    signal = medfilt(signal, kernel_size=5) #Reduces noise further

    signal = downsample(signal, original_rate=original_rate, target_rate=target_rate) #Downsample form 360Hz to 100Hz, then feed sequences of 500Hz
    return np.array(signal)
def moving_average(signal, window_size=10):
    return np.convolve(signal, np.ones(window_size)/window_size, mode='same')    
def ecg_preprocessing(signal, sample_rate = 360):
    band_passed_ecg =  nk.signal_filter(signal, sampling_rate=sample_rate, lowcut=0.5, highcut=40, method='butterworth_zi', order = 2)
    emg = moving_average(band_passed_ecg, window_size=10)
    downsampled_ecg = nk.signal_resample(emg, sampling_rate=sample_rate, desired_sampling_rate=100)
    return downsampled_ecg

# %%
def load_record(record_id, seq_len=1000, stride=1000):
    record_name = str(record_id)
    if not os.path.exists(f"mit_bih/{record_name}.dat"):
        wfdb.dl_database('mitdb', './', records=[record_name])
    record = wfdb.rdrecord('mit_bih/' + record_name)
    
    #Extract each channel
    signal_data = record.p_signal
    ch1 = ecg_preprocessing(signal_data[:, 0]).reshape(-1, 1)
    ch2 = ecg_preprocessing(signal_data[:, 1]).reshape(-1, 1)

    #Scale the signal
    scaler = MinMaxScaler(feature_range=(0, 1))
    ch1_scale = scaler.fit_transform(ch1)
    ch2_scale = scaler.fit_transform(ch2)
    
    # Create sequences using sliding window
    seq_ch1 = [ch1_scale[i:i+seq_len] for i in range(0, len(ch1_scale)-seq_len+1, stride)]
    seq_ch2 = [ch2_scale[i:i+seq_len] for i in range(0, len(ch2_scale)-seq_len+1, stride)]
    seq_ch1.extend(seq_ch2)
    return seq_ch1

def load_multiple_records(record_ranges, seq_len=1000, stride_len=100):
    all_data = []
    for start, end in tqdm(record_ranges):
        for record_id in range(start, end + 1):
            record_data = load_record(record_id, seq_len, stride_len)
            all_data.extend(record_data)
    # Save to pkl
    with open('database.pkl', 'wb') as f:
        pickle.dump(all_data, f)
    
    return all_data

# %%
def downsample(data, original_rate, target_rate):
    num_samples = int(len(data) * target_rate / original_rate)
    return resample(data, num_samples)

def calculate_l1(predictions, targets):
    l1_norm = torch.norm(predictions-targets, p=1)
    l1_sum = torch.sum(torch.abs(targets))
    accuracy = 100 * (1 - (l1_norm / l1_sum))
    return accuracy

def calculate_l2(predictions, targets):
    l2_norm = torch.norm(predictions - targets, p=2)
    l2_sum = torch.norm(targets, p=2)
    accuracy = 100 * (1 - (l2_norm / l2_sum))
    return accuracy

def calculate_MAPE(predictions, targets):
    print(len(targets))
    print(np.where(targets.cpu().numpy() == 0))
    mape = torch.mean(torch.abs((targets - predictions) / (targets + 1e-8)))
    return mape

# %%
def fixed_position_mask_peaks(rpeaks, seq, mask_length, num_peaks_to_mask):
    mask = np.zeros_like(seq, dtype=bool)  # Create a mask with the same length as seq, initially all False

    if len(rpeaks) > 0:  # If there are detected peaks
        # Randomly select 'num_peaks_to_mask' peaks from rpeaks
        selected_peaks = rpeaks[1:2*num_peaks_to_mask + 1: 2]

        for peak in selected_peaks:
            mask_half = mask_length // 2
            start = int(max(0, peak - mask_half))
            end = int(min(len(seq), peak + mask_half))
            mask[start:end] = True
    
    return mask

# %%
class ECGDataset(Dataset):
    def __init__(self, data, seq_len=1000, mask_length=60, target_rate=100,num_peaks_to_mask=1):
        """
        Args:
            data (np.array): Full ECG signal data.
            seq_len (int): Length of each sequence before downsampling.
            mask_length (int): Length of masking window around the first R-peak.
            original_rate (int): Original sampling rate of the data (default: 360 Hz).
            target_rate (int): Target sampling rate after downsampling (default: 100 Hz).
        """
        self.data = data
        self.seq_len = seq_len
        self.mask_length = mask_length
        self.target_rate = target_rate
        self.num_peaks_to_mask = num_peaks_to_mask
        
    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        # Adjust index for downsampled sequences
        seq = self.data[idx].flatten()
        # Detect R-peaks in the sequence
        rpeaks = nk.ecg_findpeaks(seq, sampling_rate=self.target_rate)['ECG_R_Peaks']

        # Create masking array
        mask = np.zeros_like(seq, dtype=bool)
        mask = fixed_position_mask_peaks(rpeaks, seq, self.mask_length, self.num_peaks_to_mask)

        masked_seq = seq.copy()
        masked_seq[mask] = 0  # Apply masking

        mask = torch.tensor(mask, dtype=torch.bool)
        return torch.tensor(masked_seq, dtype=torch.float32), torch.tensor(seq, dtype=torch.float32), mask

# %%
# Masked Autoencoder
class MAE1D(nn.Module):
    def __init__(self, seq_len, embed_dim=32, hidden_dim=64, lstm_hidden_dim=128):
        super(MAE1D, self).__init__()
        self.seq_len = seq_len
        self.encoder = nn.Sequential(
            nn.Conv1d(1, embed_dim, kernel_size=3, stride=1, padding=1),
            nn.ReLU(),
            nn.MaxPool1d(kernel_size=2, stride=2),

            nn.Conv1d(embed_dim, embed_dim * 2, kernel_size=3, stride=1, padding=1),
            nn.ReLU(),
            nn.MaxPool1d(kernel_size=2, stride=2),

            nn.Conv1d(embed_dim * 2, hidden_dim, kernel_size=3, stride=1, padding=1),
            nn.ReLU()
        )

        # BiLSTM layer, processes sequence forwards and backwars
        self.bilstm = nn.LSTM(hidden_dim, lstm_hidden_dim, bidirectional=True, batch_first=True)

        self.decoder = nn.Sequential(
            nn.Conv1d(lstm_hidden_dim * 2, embed_dim * 2, kernel_size=3, stride=1, padding=1),
            nn.ReLU(),
            nn.Upsample(scale_factor=2, mode='linear', align_corners=True),

            nn.Conv1d(embed_dim * 2, embed_dim, kernel_size=3, stride=1, padding=1),
            nn.ReLU(),
            nn.Upsample(scale_factor=2, mode='linear', align_corners=True),

            nn.Conv1d(embed_dim, 1, kernel_size=3, stride=1, padding=1)
        )

    def forward(self, x, mask):
        # print(f"Input shape: {x.shape}")
        x = x.unsqueeze(1)
        # print(f"Shape after unsqueeze (adding channel): {x.shape}")
        encoded = self.encoder(x)
        # print(f"Shape after encoding: {encoded.shape}")
        encoded = encoded.permute(0, 2, 1)
        lstm_out, _ = self.bilstm(encoded)
        
        lstm_out = lstm_out.permute(0, 2, 1)
        decoded = self.decoder(lstm_out)

        x_reconstructed = decoded.squeeze(1)
        # print(f"Shape after squeeze: {x_reconstructed.shape}")

        return x_reconstructed

# %%
# Data preparation
def prepare_data(data, seq_len, num_rpeaks,batch_size=128):
    dataset = ECGDataset(data, seq_len, num_peaks_to_mask = num_rpeaks)
    train_size = int(0.8 * len(dataset))
    val_size = len(dataset) - train_size
    train_dataset, val_dataset = random_split(dataset, [train_size, val_size])

    train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
    val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)

    return train_loader, val_loader

# %%
def evaluate_model(model, val_loader, device='cuda'):
    criterion = nn.MSELoss()
    model.eval()
    val_loss = 0.0
    l1_accuracy = 0.0
    l2_accuracy = 0.0
    MAPE_accuracy = 0.0

    model.eval()
    with torch.no_grad():
        for masked_seq, original_seq, mask in tqdm(val_loader, desc="Evaluating", leave=False):
            masked_seq, original_seq, mask = masked_seq.to(device), original_seq.to(device), mask.to(device)
            reconstructed = model(masked_seq, mask)
            masked_reconstructed = reconstructed[mask]
            masked_original = original_seq[mask]
            loss = criterion(masked_reconstructed, masked_original)
            val_loss += loss.item()
            l1_accuracy += calculate_l1(masked_reconstructed, masked_original)
            l2_accuracy += calculate_l2(masked_reconstructed, masked_original)
            MAPE_accuracy += calculate_MAPE(masked_reconstructed, masked_original)

    avg_l1 = l1_accuracy / len(val_loader)
    avg_l2 = l2_accuracy / len(val_loader)
    avg_MAPE = MAPE_accuracy / len(val_loader)

    print(f"\nValidation Loss: {val_loss / len(val_loader):.4f}")
    print(f"L1 Accuracy: {avg_l1:.4f}")
    print(f"L2 Accuracy: {avg_l2:.4f}")
    print(f"MAPE Accuracy: {avg_MAPE:.2f}%")

# %%
# Training
def train_model_with_plot(model, train_loader, val_loader, epochs, patience=10, max_hours=5, lr=0.001, file_save = 'best_model.pth',device='mps'):
    model.to(device)
    criterion = nn.MSELoss()
    optimizer = optim.Adam(model.parameters(), lr=lr)

    train_losses, val_losses = [], []

    # last best validation loss variable, set to 0.
    best_val_loss = float('inf')
    # loss patience counter
    patience_counter = 0

    start_time = time.time()
    max_time = max_hours * 3600

    for epoch in range(epochs):
        model.train()
        train_loss = 0.0
        for masked_seq, original_seq, mask in train_loader:
            masked_seq, original_seq, mask = masked_seq.to(device), original_seq.to(device), mask.to(device)

            optimizer.zero_grad()
            reconstructed = model(masked_seq, mask)

            loss_global = criterion(reconstructed, original_seq)
            loss_masked = criterion(reconstructed[mask], original_seq[mask])
            loss = 0.9 * loss_masked + 0.1 * loss_global

            loss.backward()
            optimizer.step()
            train_loss += loss.item()

        train_losses.append(train_loss / len(train_loader))

        val_loss = 0.0
        l1_accuracy = 0
        l2_accuracy = 0
        MAPE_accuracy = 0
        model.eval()
        with torch.no_grad():
            for masked_seq, original_seq, mask in val_loader:
                masked_seq, original_seq, mask = masked_seq.to(device), original_seq.to(device), mask.to(device)
                reconstructed = model(masked_seq, mask)
                masked_reconstructed = reconstructed[mask]
                masked_original = original_seq[mask]
                loss = criterion(masked_reconstructed, masked_original)
                val_loss += loss.item()
                l1_accuracy += calculate_l1(masked_reconstructed, masked_original)
                l2_accuracy += calculate_l2(masked_reconstructed, masked_original)
                MAPE_accuracy += calculate_MAPE(masked_reconstructed, masked_original)
        #print(MAPE_accuracy)
        val_losses.append(val_loss / len(val_loader))
        avg_l1 = l1_accuracy / len(val_loader)
        avg_l2 = l2_accuracy / len(val_loader)
        avg_MAPE = MAPE_accuracy / len(val_loader)
        
        print(len(val_loader))
        print(f"Epoch {epoch}, Train Loss: {train_loss / len(train_loader):.4f}, Val Loss: {val_loss / len(val_loader):.4f}, , L1 Accuracy: {avg_l1:.2f}, L2 Accuracy: {avg_l2:.2f}, MAPE Accuracy: {avg_MAPE:.2f}")

        if val_loss < best_val_loss:
            best_val_loss = val_loss
            patience_counter = 0
            torch.save(model.state_dict(), file_save)  # Save the best model
        else:
            patience_counter += 1

        if patience_counter >= patience:
            print("Early stopping triggered!")
            break
    
    evaluate_model(model, val_loader)
    # Visualize predictions vs. actual data
    plot_predictions_with_residuals(model, val_loader, device)
    plot_loss_curves(train_losses, val_losses)

# %%
def plot_some_sample(data_loader, device, num_samples=5):
    all_actual, all_masks = [], []
    with torch.no_grad():
        for masked_seq, original_seq, mask in data_loader:
            all_actual.extend(original_seq)  # original (unmasked) ECG
            all_masks.extend(mask) # Masked regions
            break
            
    plt.figure(figsize=(15, num_samples * 5))
    for i in range(min(num_samples, len(all_actual))):
        original = all_actual[i]
        mask = all_masks[i]

        # Plot predictions vs actual data
        plt.subplot(num_samples, 2, i * 2 + 1)
        plt.plot(original, label="Original", color="blue", alpha=0.7)

        # Highlight masked regions
        masked_indices = np.where(mask)[0]
        plt.scatter(masked_indices, original[masked_indices], color="red", label="Masked Regions", alpha=0.7)

        plt.title(f"Sample {i + 1} - Predictions")
        plt.legend()    
        
def plot_predictions_with_residuals(model, data_loader, device, num_samples=2):
    model.eval()
    all_actual, all_predicted, all_masks = [], [], []
    
    with torch.no_grad():
        for masked_seq, original_seq, mask in data_loader:
            masked_seq, original_seq = masked_seq.to(device), original_seq.to(device)
            reconstructed = model(masked_seq, mask)
            all_actual.extend(original_seq.cpu().numpy())  # original (unmasked) ECG
            all_predicted.extend(reconstructed.cpu().numpy())  # predictions
            all_masks.extend(mask.cpu().numpy()) # Masked regions
            break  # Take only one batch for plotting
    
    # Flatten the lists for metric calculation
    all_actual_flat = np.concatenate(all_actual)
    all_predicted_flat = np.concatenate(all_predicted)
    
    # Calculate metrics
    mse = mean_squared_error(all_actual_flat, all_predicted_flat)
    mae = mean_absolute_error(all_actual_flat, all_predicted_flat)
    r2 = r2_score(all_actual_flat, all_predicted_flat)

    print(f"Mean Squared Error (MSE): {mse:.4f}")
    print(f"Mean Absolute Error (MAE): {mae:.4f}")
    print(f"R-squared (R²): {r2:.4f}")

    # Visualize predictions vs. actual data with residuals
    plt.figure(figsize=(15, num_samples * 5))
    for i in range(min(num_samples, len(all_actual))):
        original = all_actual[i]
        predicted = all_predicted[i]
        mask = all_masks[i]

        # Plot predictions vs actual data
        plt.subplot(num_samples, 2, i * 2 + 1)
        plt.plot(original, label="Original", color="blue", alpha=0.7)
        plt.plot(predicted, label="Predicted", color="orange", alpha=0.7)

        # Highlight masked regions
        masked_indices = np.where(mask)[0]
        plt.scatter(masked_indices, original[masked_indices], color="red", label="Masked Regions", alpha=0.7)

        plt.title(f"Sample {i + 1} - Predictions")
        plt.legend()

        # Compute and plot residuals
        residuals = np.array(original) - np.array(predicted)
        plt.subplot(num_samples, 2, i * 2 + 2)
        plt.plot(residuals, label="Residuals", color="green")
        plt.axhline(0, color="black", linestyle="--")
        plt.title(f"Sample {i + 1} - Residuals")
        plt.legend()

    plt.tight_layout()
    plt.show()

def plot_loss_curves(train_losses, val_losses):
    plt.figure(figsize=(10, 5))
    plt.plot(train_losses, label="Train Loss", marker='o')
    plt.plot(val_losses, label="Validation Loss", marker='o')
    plt.xlabel("Epoch")
    plt.ylabel("Loss")
    plt.title("Loss Curves")
    plt.legend()
    plt.grid()
    plt.show()

def plot_ecg_sample_no_mask(data, num_samples=2):
    # Visualize predictions vs. actual data with residuals
    fig, ax = plt.subplots(1, num_samples, figsize = (16,9))
    ax = ax.flatten()
    for i in range(0, num_samples):
        # Plot predictions vs actual data
        ax[i].plot(data[i], label="Original", color="blue", alpha=0.7)
    plt.tight_layout()
    plt.show()

# %%
record_ranges = [(100,109),(111, 119),(121,124),(200,203),(205,205),(207,210),(212,215),(217,217),(219,223),(228,228),(230,234)]
print("Working with data")
seq_len = 1000
data = np.array(load_multiple_records(record_ranges, 1000, 100))
train_loader, val_loader = prepare_data(data,num_rpeaks = num, seq_len=seq_len)
# Out:
# Working with data
# 100%|████████████████████████████████████████████████████████████████████████████████| 11/11 [00:03<00:00,  2.82it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[113], line 4
#       2 print("Working with data")
#       3 seq_len = 1000
# ----> 4 data = np.array(load_multiple_records(record_ranges, 1000, 100))
#       5 train_loader, val_loader = prepare_data(data,num_rpeaks = num, seq_len=seq_len)
#
# KeyboardInterrupt:

# %%
plot_ecg_sample_no_mask(data, num_samples=2)

# %%
plot_ecg_sample_no_mask(data, num_samples=2)

# %%
record_ranges = [(100,109),(111, 119),(121,124),(200,203),(205,205),(207,210),(212,215),(217,217),(219,223),(228,228),(230,234)]
print("Working with data")
seq_len = 5000
data = np.array(load_multiple_records(record_ranges, 5000, 4000))
print(data.shape)
for num in [8]:
    print("="*20)
    print(f"Training the model with {num} R peaks")
    print("="*20)
    
    print("Preparing the data")
    train_loader, val_loader = prepare_data(data,num_rpeaks = num, seq_len=seq_len)
    
    print("Training the model")
    mae_model = MAE1D(seq_len=seq_len)
    train_model_with_plot(mae_model, train_loader, val_loader, epochs=60, device='cuda', file_save = f'best_model_{num}_1_rpeaks.pth')
# Out:
# Working with data
# 100%|████████████████████████████████████████████████████████████████████████████████| 11/11 [00:03<00:00,  2.84it/s]
# (4224, 5000, 1)
# ====================
# Training the model with 8 R peaks
# ====================
# Preparing the data
# Training the model
# 61440
# (array([], dtype=int64),)
# 60900
# (array([46833, 47313]),)
# 60240
# (array([], dtype=int64),)
# 59580
# (array([], dtype=int64),)
# 61080
# (array([], dtype=int64),)
# 60180
# (array([  506, 56091]),)
# 36120
# (array([], dtype=int64),)
# 7
# Epoch 0, Train Loss: 0.0690, Val Loss: 0.0199, , L1 Accuracy: 77.12, L2 Accuracy: 72.64, MAPE Accuracy: inf
# 61440
# (array([], dtype=int64),)
# 60900
# (array([46833, 47313]),)
# 60240
# (array([], dtype=int64),)
# 59580
# (array([], dtype=int64),)
# 61080
# (array([], dtype=int64),)
# 60180
# (array([  506, 56091]),)
# 36120
# (array([], dtype=int64),)
# 7
# Epoch 1, Train Loss: 0.0181, Val Loss: 0.0181, , L1 Accuracy: 78.21, L2 Accuracy: 73.89, MAPE Accuracy: inf
# 61440
# (array([], dtype=int64),)
# 60900
# (array([46833, 47313]),)
# 60240
# (array([], dtype=int64),)
# 59580
# (array([], dtype=int64),)
# 61080
# (array([], dtype=int64),)
# 60180
# (array([  506, 56091]),)
# 36120
# (array([], dtype=int64),)
# 7
# Epoch 2, Train Loss: 0.0164, Val Loss: 0.0167, , L1 Accuracy: 79.29, L2 Accuracy: 74.94, MAPE Accuracy: inf
# 61440
# (array([], dtype=int64),)
# 60900
# (array([46833, 47313]),)
# 60240
# (array([], dtype=int64),)
# 59580
# (array([], dtype=int64),)
# 61080
# (array([], dtype=int64),)
# 60180
# (array([  506, 56091]),)
# 36120
# (array([], dtype=int64),)
# 7
# Epoch 3, Train Loss: 0.0147, Val Loss: 0.0138, , L1 Accuracy: 81.88, L2 Accuracy: 77.21, MAPE Accuracy: inf
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[130], line 16
#      14 print("Training the model")
#      15 mae_model = MAE1D(seq_len=seq_len)
# ---> 16 train_model_with_plot(mae_model, train_loader, val_loader, epochs=60, device='cuda', file_save = f'best_model_{num}_1_rpeaks.pth')
#
# Cell In[124], line 20, in train_model_with_plot(model, train_loader, val_loader, epochs, patience, max_hours, lr, file_save, device)
#      18 model.train()
#      19 train_loss = 0.0
# ---> 20 for masked_seq, original_seq, mask in train_loader:
#      21     masked_seq, original_seq, mask = masked_seq.to(device), original_seq.to(device), mask.to(device)
#      23     optimizer.zero_grad()
#
# File ~/miniconda3/envs/torch-gpu/lib/python3.10/site-packages/torch/utils/data/dataloader.py:701, in _BaseDataLoaderIter.__next__(self)
#     698 if self._sampler_iter is None:
#     699     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     700     self._reset()  # type: ignore[call-arg]
# --> 701 data = self._next_data()
#     702 self._num_yielded += 1
#     703 if (
#     704     self._dataset_kind == _DatasetKind.Iterable
#     705     and self._IterableDataset_len_called is not None
#     706     and self._num_yielded > self._IterableDataset_len_called
#     707 ):
#
# File ~/miniconda3/envs/torch-gpu/lib/python3.10/site-packages/torch/utils/data/dataloader.py:757, in _SingleProcessDataLoaderIter._next_data(self)
#     755 def _next_data(self):
#     756     index = self._next_index()  # may raise StopIteration
# --> 757     data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     758     if self._pin_memory:
#     759         data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# File ~/miniconda3/envs/torch-gpu/lib/python3.10/site-packages/torch/utils/data/_utils/fetch.py:50, in _MapDatasetFetcher.fetch(self, possibly_batched_index)
#      48 if self.auto_collation:
#      49     if hasattr(self.dataset, "__getitems__") and self.dataset.__getitems__:
# ---> 50         data = self.dataset.__getitems__(possibly_batched_index)
#      51     else:
#      52         data = [self.dataset[idx] for idx in possibly_batched_index]
#
# File ~/miniconda3/envs/torch-gpu/lib/python3.10/site-packages/torch/utils/data/dataset.py:420, in Subset.__getitems__(self, indices)
#     418     return self.dataset.__getitems__([self.indices[idx] for idx in indices])  # type: ignore[attr-defined]
#     419 else:
# --> 420     return [self.dataset[self.indices[idx]] for idx in indices]
#
# File ~/miniconda3/envs/torch-gpu/lib/python3.10/site-packages/torch/utils/data/dataset.py:420, in <listcomp>(.0)
#     418     return self.dataset.__getitems__([self.indices[idx] for idx in indices])  # type: ignore[attr-defined]
#     419 else:
# --> 420     return [self.dataset[self.indices[idx]] for idx in indices]
#
# Cell In[107], line 33, in ECGDataset.__getitem__(self, idx)
#      30 masked_seq = seq.copy()
#      31 masked_seq[mask] = 0  # Apply masking
# ---> 33 mask = torch.tensor(mask, dtype=torch.bool)
#      34 return torch.tensor(masked_seq, dtype=torch.float32), torch.tensor(seq, dtype=torch.float32), mask
#
# KeyboardInterrupt:

# %%
test_data = load_multiple_records([(233,234)])
test_dataset = ECGDataset(test_data, seq_len, num_peaks_to_mask = 2)
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False)
evaluate_model(mae_model, val_loader, device='cuda')
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  3.25it/s]
# Validation Loss: 0.0024
# L1 Accuracy: 95.9639
# L2 Accuracy: 91.5880
# MAPE Accuracy: 0.04%

# %%
from torch.utils.data import DataLoader, TensorDataset

def load_wesad_dataset(root_dir, test_subject):
    folder_ls = os.listdir(root_dir)
    for i in folder_ls:
        if i == ".ipynb_checkpoints" or i == '.DS_Store':
            print(f"Removing {i}")
            folder_ls.remove(i)
    
    valid_ls = ['S2']
    train_ls = [subject for subject in folder_ls if subject not in valid_ls]

    # Create the train list by excluding test_ls
    train_ls = [subject for subject in folder_ls if subject not in valid_ls]
    print("==========Loading Training set============")
    X_train, y_train = load_process_extract_ls(root_dir, train_ls,700, 5,5,True)
    print("==========Loading Testing set============")
    X_test, y_test = load_process_extract_ls(root_dir,valid_ls,700, 5, 5,False)
    return X_train, X_test, y_train, y_test
    
class ECGClassificationDataset(Dataset):
    def __init__(self, X, Y):
        self.X = X  # shape: [N, L]
        self.Y = Y  # shape: [N]
    def __len__(self):
        return len(self.X)

    def __getitem__(self, idx):
        seq = self.X[idx].flatten()
        return torch.tensor(seq, dtype=torch.float32).unsqueeze(0), torch.tensor(self.Y[idx], dtype=torch.long)

# %%
from data_processing_qrs_80f1 import *
X_train, X_test, y_train, y_test = load_wesad_dataset('/home/van/NamQuang/ECG_Research/WESAD_LOSO', 'S2.pkl')
train_dataloader = ECGClassificationDataset(X_train, y_train)
test_dataloader = ECGClassificationDataset(X_test, y_test)
# Out:
# Removing .DS_Store
# ==========Loading Training set============
# 5-15
# remove nonstress: 1
# Working with: /home/van/NamQuang/ECG_Research/WESAD_LOSO/S16/S16.pkl
# 5-15
# remove nonstress: 17
# Working with: /home/van/NamQuang/ECG_Research/WESAD_LOSO/S9/S9.pkl
# 5-15
# remove nonstress: 26
# Working with: /home/van/NamQuang/ECG_Research/WESAD_LOSO/S13/S13.pkl
# 5-15
# remove nonstress: 2
# Working with: /home/van/NamQuang/ECG_Research/WESAD_LOSO/S8/S8.pkl
# 5-15
# remove nonstress: 5
# Working with: /home/van/NamQuang/ECG_Research/WESAD_LOSO/S4/S4.pkl
# 5-15
# remove nonstress: 0
# Working with: /home/van/NamQuang/ECG_Research/WESAD_LOSO/S11/S11.pkl
# 5-15
# remove nonstress: 23
# Working with: /home/van/NamQuang/ECG_Research/WESAD_LOSO/S15/S15.pkl
# 5-15
# remove nonstress: 2
# Working with: /home/van/NamQuang/ECG_Research/WESAD_LOSO/S3/S3.pkl
# 5-15
# remove nonstress: 2
# Working with: /home/van/NamQuang/ECG_Research/WESAD_LOSO/S6/S6.pkl
# 5-15
# remove nonstress: 5
# Working with: /home/van/NamQuang/ECG_Research/WESAD_LOSO/S7/S7.pkl
# 5-15
# remove nonstress: 0
# Working with: /home/van/NamQuang/ECG_Research/WESAD_LOSO/S14/S14.pkl
# 5-15
# remove nonstress: 11
# Working with: /home/van/NamQuang/ECG_Research/WESAD_LOSO/S10/S10.pkl
# 5-15
# remove nonstress: 1
# Working with: /home/van/NamQuang/ECG_Research/WESAD_LOSO/S5/S5.pkl
# 5-15
# remove nonstress: 2
# Working with: /home/van/NamQuang/ECG_Research/WESAD_LOSO/S17/S17.pkl
# ==========Loading Testing set============
# 5-15
# remove nonstress: 0
# Working with: /home/van/NamQuang/ECG_Research/WESAD_LOSO/S2/S2.pkl

# %%
train_size = int(0.8 * len(train_dataloader))
val_size = len(train_dataloader) - train_size
train_dataset, val_dataset = random_split(train_dataloader, [train_size, val_size])

train_loader_wesad = DataLoader(train_dataset, batch_size=128, shuffle=True)
val_loader_wesad = DataLoader(val_dataset, batch_size=128, shuffle=False)
test_loader_wesad = DataLoader(test_dataloader, batch_size=128, shuffle=False)

# %%
import torch.nn.functional as F


class DownstreamClassifier(nn.Module):
    def __init__(self, encoder, hidden_dim = 64, num_classes=2):
        super(DownstreamClassifier, self).__init__()
        self.encoder = encoder
        # Freeze encoder parameters
        for param in self.encoder.parameters():
            param.requires_grad = False
        
        # Classifier head after GAP
        self.classifier = nn.Sequential(
            nn.Linear(hidden_dim, 128),  # hidden_dim = last conv channels output
            nn.ReLU(),
            nn.Linear(128, num_classes)
        )

    def forward(self, x):
        with torch.no_grad():
            z = self.encoder(x)  # shape: (B, C=hidden_dim, L)
        
        # Global Average Pooling over the sequence dimension (L)
        z = F.adaptive_avg_pool1d(z, 1)  # shape: (B, C, 1)
        z = z.squeeze(-1)                 # shape: (B, C)
        logits = self.classifier(z)
        return logits

# %%
# Load model and pretrained weights
auto_model = MAE1D(seq_len = 1000)
auto_model.load_state_dict(torch.load('best_model_8_5_rpeaks.pth', weights_only=True))
frozen_encoder = auto_model.encoder
model = DownstreamClassifier(frozen_encoder)

# Move to device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(filter(lambda p: p.requires_grad, model.parameters()), lr=1e-3)

# Train loop
model.train()
num_epochs = 200

val_losses = []

for epoch in range(num_epochs):
    # --- Training ---
    model.train()
    total_loss = 0
    all_train_preds = []
    all_train_labels = []

    for x, y in train_loader_wesad:
        x, y = x.to(device), y.to(device)
        outputs = model(x)
        loss = criterion(outputs, y)

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        total_loss += loss.item()

        preds = torch.argmax(outputs, dim=1)
        all_train_preds.extend(preds.cpu().numpy())
        all_train_labels.extend(y.cpu().numpy())

    train_accuracy = accuracy_score(all_train_labels, all_train_preds)
    train_f1_macro = f1_score(all_train_labels, all_train_preds, average='macro')

    # --- Validation ---
    model.eval()
    val_loss = 0.0
    all_val_preds = []
    all_val_labels = []

    with torch.no_grad():
        for x_val, y_val in val_loader_wesad:
            x_val, y_val = x_val.to(device), y_val.to(device)
            outputs = model(x_val)
            loss = criterion(outputs, y_val)
            val_loss += loss.item()

            preds = torch.argmax(outputs, dim=1)
            all_val_preds.extend(preds.cpu().numpy())
            all_val_labels.extend(y_val.cpu().numpy())

    avg_val_loss = val_loss / len(val_loader)
    val_accuracy = accuracy_score(all_val_labels, all_val_preds)
    val_f1_macro = f1_score(all_val_labels, all_val_preds, average='macro')
    val_losses.append(avg_val_loss)

    print(f"Epoch {epoch}: "
          f"Train Loss = {total_loss/len(train_loader):.4f}, "
          f"Train Acc = {train_accuracy:.4f}, "
          f"Train F1 = {train_f1_macro:.4f} | "
          f"Val Loss = {avg_val_loss:.4f}, "
          f"Val Acc = {val_accuracy:.4f}, "
          f"Val F1 = {val_f1_macro:.4f}")
# Out:
# Epoch 0: Train Loss = 0.0299, Train Acc = 0.7637, Train F1 = 0.4494 | Val Loss = 0.0272, Val Acc = 0.7750, Val F1 = 0.4392
# Epoch 1: Train Loss = 0.0255, Train Acc = 0.7857, Train F1 = 0.4836 | Val Loss = 0.0237, Val Acc = 0.7895, Val F1 = 0.5030
# Epoch 2: Train Loss = 0.0229, Train Acc = 0.8093, Train F1 = 0.6113 | Val Loss = 0.0215, Val Acc = 0.8252, Val F1 = 0.6435
# Epoch 3: Train Loss = 0.0215, Train Acc = 0.8200, Train F1 = 0.6663 | Val Loss = 0.0201, Val Acc = 0.8367, Val F1 = 0.6840
# Epoch 4: Train Loss = 0.0204, Train Acc = 0.8253, Train F1 = 0.6899 | Val Loss = 0.0193, Val Acc = 0.8482, Val F1 = 0.7474
# Epoch 5: Train Loss = 0.0188, Train Acc = 0.8424, Train F1 = 0.7180 | Val Loss = 0.0183, Val Acc = 0.8391, Val F1 = 0.6866
# Epoch 6: Train Loss = 0.0181, Train Acc = 0.8474, Train F1 = 0.7314 | Val Loss = 0.0179, Val Acc = 0.8651, Val F1 = 0.7951
# Epoch 7: Train Loss = 0.0172, Train Acc = 0.8586, Train F1 = 0.7542 | Val Loss = 0.0166, Val Acc = 0.8621, Val F1 = 0.7492
# Epoch 8: Train Loss = 0.0165, Train Acc = 0.8630, Train F1 = 0.7682 | Val Loss = 0.0192, Val Acc = 0.8306, Val F1 = 0.7826
# Epoch 9: Train Loss = 0.0162, Train Acc = 0.8681, Train F1 = 0.7824 | Val Loss = 0.0155, Val Acc = 0.8820, Val F1 = 0.8038
# Epoch 10: Train Loss = 0.0155, Train Acc = 0.8728, Train F1 = 0.7889 | Val Loss = 0.0151, Val Acc = 0.8857, Val F1 = 0.8175
# Epoch 11: Train Loss = 0.0152, Train Acc = 0.8790, Train F1 = 0.8022 | Val Loss = 0.0147, Val Acc = 0.8838, Val F1 = 0.8117
# Epoch 12: Train Loss = 0.0149, Train Acc = 0.8825, Train F1 = 0.8098 | Val Loss = 0.0145, Val Acc = 0.8826, Val F1 = 0.8025
# Epoch 13: Train Loss = 0.0144, Train Acc = 0.8847, Train F1 = 0.8129 | Val Loss = 0.0143, Val Acc = 0.8808, Val F1 = 0.7981
# Epoch 14: Train Loss = 0.0144, Train Acc = 0.8825, Train F1 = 0.8114 | Val Loss = 0.0141, Val Acc = 0.8905, Val F1 = 0.8341
# Epoch 15: Train Loss = 0.0149, Train Acc = 0.8784, Train F1 = 0.8058 | Val Loss = 0.0136, Val Acc = 0.8953, Val F1 = 0.8361
# Epoch 16: Train Loss = 0.0137, Train Acc = 0.8888, Train F1 = 0.8237 | Val Loss = 0.0158, Val Acc = 0.8584, Val F1 = 0.7355
# Epoch 17: Train Loss = 0.0137, Train Acc = 0.8882, Train F1 = 0.8211 | Val Loss = 0.0135, Val Acc = 0.8996, Val F1 = 0.8489
# Epoch 18: Train Loss = 0.0140, Train Acc = 0.8878, Train F1 = 0.8232 | Val Loss = 0.0130, Val Acc = 0.8972, Val F1 = 0.8380
# Epoch 19: Train Loss = 0.0132, Train Acc = 0.8932, Train F1 = 0.8323 | Val Loss = 0.0128, Val Acc = 0.9002, Val F1 = 0.8388
# Epoch 20: Train Loss = 0.0130, Train Acc = 0.8988, Train F1 = 0.8407 | Val Loss = 0.0139, Val Acc = 0.8972, Val F1 = 0.8542
# Epoch 21: Train Loss = 0.0128, Train Acc = 0.8985, Train F1 = 0.8410 | Val Loss = 0.0128, Val Acc = 0.9032, Val F1 = 0.8559
# Epoch 22: Train Loss = 0.0127, Train Acc = 0.8991, Train F1 = 0.8418 | Val Loss = 0.0125, Val Acc = 0.9056, Val F1 = 0.8562
# Epoch 23: Train Loss = 0.0126, Train Acc = 0.9014, Train F1 = 0.8461 | Val Loss = 0.0122, Val Acc = 0.9074, Val F1 = 0.8597
# Epoch 24: Train Loss = 0.0124, Train Acc = 0.8997, Train F1 = 0.8438 | Val Loss = 0.0124, Val Acc = 0.8972, Val F1 = 0.8287
# Epoch 25: Train Loss = 0.0122, Train Acc = 0.9023, Train F1 = 0.8482 | Val Loss = 0.0119, Val Acc = 0.9062, Val F1 = 0.8504
# Epoch 26: Train Loss = 0.0121, Train Acc = 0.9043, Train F1 = 0.8502 | Val Loss = 0.0122, Val Acc = 0.9062, Val F1 = 0.8623
# Epoch 27: Train Loss = 0.0118, Train Acc = 0.9076, Train F1 = 0.8567 | Val Loss = 0.0125, Val Acc = 0.9056, Val F1 = 0.8645
# Epoch 28: Train Loss = 0.0119, Train Acc = 0.9050, Train F1 = 0.8527 | Val Loss = 0.0114, Val Acc = 0.9153, Val F1 = 0.8672
# Epoch 29: Train Loss = 0.0115, Train Acc = 0.9076, Train F1 = 0.8568 | Val Loss = 0.0116, Val Acc = 0.9038, Val F1 = 0.8424
# Epoch 30: Train Loss = 0.0116, Train Acc = 0.9109, Train F1 = 0.8626 | Val Loss = 0.0112, Val Acc = 0.9147, Val F1 = 0.8645
# Epoch 31: Train Loss = 0.0120, Train Acc = 0.9027, Train F1 = 0.8503 | Val Loss = 0.0112, Val Acc = 0.9165, Val F1 = 0.8685
# Epoch 32: Train Loss = 0.0113, Train Acc = 0.9074, Train F1 = 0.8566 | Val Loss = 0.0124, Val Acc = 0.9032, Val F1 = 0.8636
# Epoch 33: Train Loss = 0.0119, Train Acc = 0.9053, Train F1 = 0.8545 | Val Loss = 0.0113, Val Acc = 0.9141, Val F1 = 0.8737
# Epoch 34: Train Loss = 0.0111, Train Acc = 0.9108, Train F1 = 0.8620 | Val Loss = 0.0107, Val Acc = 0.9208, Val F1 = 0.8778
# Epoch 35: Train Loss = 0.0111, Train Acc = 0.9108, Train F1 = 0.8623 | Val Loss = 0.0107, Val Acc = 0.9165, Val F1 = 0.8728
# Epoch 36: Train Loss = 0.0109, Train Acc = 0.9123, Train F1 = 0.8649 | Val Loss = 0.0115, Val Acc = 0.9050, Val F1 = 0.8640
# Epoch 37: Train Loss = 0.0115, Train Acc = 0.9064, Train F1 = 0.8569 | Val Loss = 0.0127, Val Acc = 0.8984, Val F1 = 0.8612
# Epoch 38: Train Loss = 0.0107, Train Acc = 0.9145, Train F1 = 0.8687 | Val Loss = 0.0106, Val Acc = 0.9177, Val F1 = 0.8775
# Epoch 39: Train Loss = 0.0109, Train Acc = 0.9136, Train F1 = 0.8684 | Val Loss = 0.0113, Val Acc = 0.9032, Val F1 = 0.8388
# Epoch 40: Train Loss = 0.0108, Train Acc = 0.9120, Train F1 = 0.8648 | Val Loss = 0.0105, Val Acc = 0.9195, Val F1 = 0.8765
# Epoch 41: Train Loss = 0.0106, Train Acc = 0.9154, Train F1 = 0.8702 | Val Loss = 0.0122, Val Acc = 0.9062, Val F1 = 0.8712
# Epoch 42: Train Loss = 0.0109, Train Acc = 0.9117, Train F1 = 0.8656 | Val Loss = 0.0114, Val Acc = 0.9111, Val F1 = 0.8745
# Epoch 43: Train Loss = 0.0106, Train Acc = 0.9164, Train F1 = 0.8723 | Val Loss = 0.0106, Val Acc = 0.9129, Val F1 = 0.8585
# Epoch 44: Train Loss = 0.0103, Train Acc = 0.9162, Train F1 = 0.8716 | Val Loss = 0.0100, Val Acc = 0.9214, Val F1 = 0.8778
# Epoch 45: Train Loss = 0.0101, Train Acc = 0.9168, Train F1 = 0.8726 | Val Loss = 0.0099, Val Acc = 0.9201, Val F1 = 0.8791
# Epoch 46: Train Loss = 0.0104, Train Acc = 0.9180, Train F1 = 0.8752 | Val Loss = 0.0100, Val Acc = 0.9220, Val F1 = 0.8825
# Epoch 47: Train Loss = 0.0101, Train Acc = 0.9176, Train F1 = 0.8737 | Val Loss = 0.0098, Val Acc = 0.9226, Val F1 = 0.8818
# Epoch 48: Train Loss = 0.0113, Train Acc = 0.9065, Train F1 = 0.8584 | Val Loss = 0.0106, Val Acc = 0.9147, Val F1 = 0.8778
# Epoch 49: Train Loss = 0.0099, Train Acc = 0.9198, Train F1 = 0.8780 | Val Loss = 0.0102, Val Acc = 0.9159, Val F1 = 0.8645
# Epoch 50: Train Loss = 0.0098, Train Acc = 0.9216, Train F1 = 0.8802 | Val Loss = 0.0106, Val Acc = 0.9123, Val F1 = 0.8573
# Epoch 51: Train Loss = 0.0100, Train Acc = 0.9195, Train F1 = 0.8775 | Val Loss = 0.0107, Val Acc = 0.9099, Val F1 = 0.8515
# Epoch 52: Train Loss = 0.0102, Train Acc = 0.9157, Train F1 = 0.8714 | Val Loss = 0.0097, Val Acc = 0.9238, Val F1 = 0.8875
# Epoch 53: Train Loss = 0.0102, Train Acc = 0.9170, Train F1 = 0.8733 | Val Loss = 0.0102, Val Acc = 0.9226, Val F1 = 0.8879
# Epoch 54: Train Loss = 0.0097, Train Acc = 0.9192, Train F1 = 0.8772 | Val Loss = 0.0094, Val Acc = 0.9256, Val F1 = 0.8880
# Epoch 55: Train Loss = 0.0096, Train Acc = 0.9244, Train F1 = 0.8849 | Val Loss = 0.0102, Val Acc = 0.9153, Val F1 = 0.8631
# Epoch 56: Train Loss = 0.0105, Train Acc = 0.9173, Train F1 = 0.8744 | Val Loss = 0.0095, Val Acc = 0.9244, Val F1 = 0.8810
# Epoch 57: Train Loss = 0.0098, Train Acc = 0.9209, Train F1 = 0.8791 | Val Loss = 0.0093, Val Acc = 0.9250, Val F1 = 0.8867
# Epoch 58: Train Loss = 0.0097, Train Acc = 0.9197, Train F1 = 0.8790 | Val Loss = 0.0111, Val Acc = 0.9050, Val F1 = 0.8412
# Epoch 59: Train Loss = 0.0101, Train Acc = 0.9188, Train F1 = 0.8769 | Val Loss = 0.0094, Val Acc = 0.9232, Val F1 = 0.8797
# Epoch 60: Train Loss = 0.0094, Train Acc = 0.9227, Train F1 = 0.8824 | Val Loss = 0.0106, Val Acc = 0.9099, Val F1 = 0.8508
# Epoch 61: Train Loss = 0.0099, Train Acc = 0.9164, Train F1 = 0.8729 | Val Loss = 0.0107, Val Acc = 0.9147, Val F1 = 0.8812
# Epoch 62: Train Loss = 0.0111, Train Acc = 0.9080, Train F1 = 0.8609 | Val Loss = 0.0094, Val Acc = 0.9220, Val F1 = 0.8799
# Epoch 63: Train Loss = 0.0093, Train Acc = 0.9256, Train F1 = 0.8871 | Val Loss = 0.0091, Val Acc = 0.9238, Val F1 = 0.8836
# Epoch 64: Train Loss = 0.0093, Train Acc = 0.9245, Train F1 = 0.8850 | Val Loss = 0.0091, Val Acc = 0.9244, Val F1 = 0.8854
# Epoch 65: Train Loss = 0.0093, Train Acc = 0.9230, Train F1 = 0.8834 | Val Loss = 0.0091, Val Acc = 0.9244, Val F1 = 0.8844
# Epoch 66: Train Loss = 0.0092, Train Acc = 0.9236, Train F1 = 0.8842 | Val Loss = 0.0093, Val Acc = 0.9232, Val F1 = 0.8780
# Epoch 67: Train Loss = 0.0092, Train Acc = 0.9248, Train F1 = 0.8861 | Val Loss = 0.0110, Val Acc = 0.9074, Val F1 = 0.8460
# Epoch 68: Train Loss = 0.0092, Train Acc = 0.9226, Train F1 = 0.8824 | Val Loss = 0.0089, Val Acc = 0.9298, Val F1 = 0.8953
# Epoch 69: Train Loss = 0.0091, Train Acc = 0.9248, Train F1 = 0.8864 | Val Loss = 0.0089, Val Acc = 0.9274, Val F1 = 0.8906
# Epoch 70: Train Loss = 0.0092, Train Acc = 0.9244, Train F1 = 0.8855 | Val Loss = 0.0091, Val Acc = 0.9274, Val F1 = 0.8887
# Epoch 71: Train Loss = 0.0094, Train Acc = 0.9232, Train F1 = 0.8841 | Val Loss = 0.0091, Val Acc = 0.9310, Val F1 = 0.8963
# Epoch 72: Train Loss = 0.0090, Train Acc = 0.9235, Train F1 = 0.8844 | Val Loss = 0.0089, Val Acc = 0.9310, Val F1 = 0.8990
# Epoch 73: Train Loss = 0.0089, Train Acc = 0.9289, Train F1 = 0.8925 | Val Loss = 0.0089, Val Acc = 0.9268, Val F1 = 0.8907
# Epoch 74: Train Loss = 0.0090, Train Acc = 0.9263, Train F1 = 0.8884 | Val Loss = 0.0092, Val Acc = 0.9262, Val F1 = 0.8942
# Epoch 75: Train Loss = 0.0103, Train Acc = 0.9141, Train F1 = 0.8707 | Val Loss = 0.0098, Val Acc = 0.9268, Val F1 = 0.8977
# Epoch 76: Train Loss = 0.0087, Train Acc = 0.9271, Train F1 = 0.8893 | Val Loss = 0.0092, Val Acc = 0.9274, Val F1 = 0.8967
# Epoch 77: Train Loss = 0.0090, Train Acc = 0.9283, Train F1 = 0.8916 | Val Loss = 0.0087, Val Acc = 0.9298, Val F1 = 0.8958
# Epoch 78: Train Loss = 0.0088, Train Acc = 0.9295, Train F1 = 0.8944 | Val Loss = 0.0125, Val Acc = 0.8893, Val F1 = 0.8068
# Epoch 79: Train Loss = 0.0096, Train Acc = 0.9221, Train F1 = 0.8826 | Val Loss = 0.0087, Val Acc = 0.9292, Val F1 = 0.8950
# Epoch 80: Train Loss = 0.0087, Train Acc = 0.9292, Train F1 = 0.8929 | Val Loss = 0.0087, Val Acc = 0.9298, Val F1 = 0.8976
# Epoch 81: Train Loss = 0.0088, Train Acc = 0.9277, Train F1 = 0.8911 | Val Loss = 0.0085, Val Acc = 0.9298, Val F1 = 0.8931
# Epoch 82: Train Loss = 0.0091, Train Acc = 0.9247, Train F1 = 0.8872 | Val Loss = 0.0085, Val Acc = 0.9328, Val F1 = 0.9006
# Epoch 83: Train Loss = 0.0086, Train Acc = 0.9294, Train F1 = 0.8938 | Val Loss = 0.0087, Val Acc = 0.9328, Val F1 = 0.8997
# Epoch 84: Train Loss = 0.0090, Train Acc = 0.9253, Train F1 = 0.8880 | Val Loss = 0.0099, Val Acc = 0.9165, Val F1 = 0.8644
# Epoch 85: Train Loss = 0.0087, Train Acc = 0.9266, Train F1 = 0.8894 | Val Loss = 0.0087, Val Acc = 0.9274, Val F1 = 0.8872
# Epoch 86: Train Loss = 0.0088, Train Acc = 0.9286, Train F1 = 0.8927 | Val Loss = 0.0084, Val Acc = 0.9335, Val F1 = 0.9003
# Epoch 87: Train Loss = 0.0091, Train Acc = 0.9257, Train F1 = 0.8887 | Val Loss = 0.0092, Val Acc = 0.9226, Val F1 = 0.8757
# Epoch 88: Train Loss = 0.0086, Train Acc = 0.9291, Train F1 = 0.8936 | Val Loss = 0.0083, Val Acc = 0.9322, Val F1 = 0.8963
# Epoch 89: Train Loss = 0.0083, Train Acc = 0.9315, Train F1 = 0.8968 | Val Loss = 0.0084, Val Acc = 0.9292, Val F1 = 0.8913
# Epoch 90: Train Loss = 0.0083, Train Acc = 0.9315, Train F1 = 0.8971 | Val Loss = 0.0087, Val Acc = 0.9268, Val F1 = 0.8843
# Epoch 91: Train Loss = 0.0082, Train Acc = 0.9316, Train F1 = 0.8967 | Val Loss = 0.0085, Val Acc = 0.9262, Val F1 = 0.8843
# Epoch 92: Train Loss = 0.0084, Train Acc = 0.9288, Train F1 = 0.8926 | Val Loss = 0.0081, Val Acc = 0.9353, Val F1 = 0.9045
# Epoch 93: Train Loss = 0.0093, Train Acc = 0.9239, Train F1 = 0.8858 | Val Loss = 0.0088, Val Acc = 0.9274, Val F1 = 0.8848
# Epoch 94: Train Loss = 0.0089, Train Acc = 0.9269, Train F1 = 0.8905 | Val Loss = 0.0080, Val Acc = 0.9377, Val F1 = 0.9056
# Epoch 95: Train Loss = 0.0084, Train Acc = 0.9312, Train F1 = 0.8968 | Val Loss = 0.0081, Val Acc = 0.9359, Val F1 = 0.9039
# Epoch 96: Train Loss = 0.0086, Train Acc = 0.9297, Train F1 = 0.8950 | Val Loss = 0.0084, Val Acc = 0.9335, Val F1 = 0.9031
# Epoch 97: Train Loss = 0.0084, Train Acc = 0.9339, Train F1 = 0.9006 | Val Loss = 0.0084, Val Acc = 0.9292, Val F1 = 0.8904
# Epoch 98: Train Loss = 0.0081, Train Acc = 0.9330, Train F1 = 0.8999 | Val Loss = 0.0081, Val Acc = 0.9365, Val F1 = 0.9048
# Epoch 99: Train Loss = 0.0081, Train Acc = 0.9337, Train F1 = 0.9005 | Val Loss = 0.0080, Val Acc = 0.9341, Val F1 = 0.8992
# Epoch 100: Train Loss = 0.0080, Train Acc = 0.9324, Train F1 = 0.8986 | Val Loss = 0.0079, Val Acc = 0.9371, Val F1 = 0.9052
# Epoch 101: Train Loss = 0.0082, Train Acc = 0.9344, Train F1 = 0.9019 | Val Loss = 0.0080, Val Acc = 0.9389, Val F1 = 0.9084
# Epoch 102: Train Loss = 0.0082, Train Acc = 0.9324, Train F1 = 0.8985 | Val Loss = 0.0082, Val Acc = 0.9341, Val F1 = 0.9005
# Epoch 103: Train Loss = 0.0083, Train Acc = 0.9300, Train F1 = 0.8957 | Val Loss = 0.0090, Val Acc = 0.9238, Val F1 = 0.8779
# Epoch 104: Train Loss = 0.0081, Train Acc = 0.9345, Train F1 = 0.9017 | Val Loss = 0.0079, Val Acc = 0.9389, Val F1 = 0.9091
# Epoch 105: Train Loss = 0.0084, Train Acc = 0.9318, Train F1 = 0.8985 | Val Loss = 0.0099, Val Acc = 0.9147, Val F1 = 0.8606
# Epoch 106: Train Loss = 0.0082, Train Acc = 0.9336, Train F1 = 0.9000 | Val Loss = 0.0079, Val Acc = 0.9365, Val F1 = 0.9082
# Epoch 107: Train Loss = 0.0078, Train Acc = 0.9369, Train F1 = 0.9058 | Val Loss = 0.0083, Val Acc = 0.9335, Val F1 = 0.8968
# Epoch 108: Train Loss = 0.0080, Train Acc = 0.9354, Train F1 = 0.9031 | Val Loss = 0.0079, Val Acc = 0.9298, Val F1 = 0.8912
# Epoch 109: Train Loss = 0.0082, Train Acc = 0.9301, Train F1 = 0.8952 | Val Loss = 0.0082, Val Acc = 0.9298, Val F1 = 0.8900
# Epoch 110: Train Loss = 0.0087, Train Acc = 0.9321, Train F1 = 0.8984 | Val Loss = 0.0081, Val Acc = 0.9371, Val F1 = 0.9096
# Epoch 111: Train Loss = 0.0084, Train Acc = 0.9313, Train F1 = 0.8970 | Val Loss = 0.0077, Val Acc = 0.9389, Val F1 = 0.9095
# Epoch 112: Train Loss = 0.0078, Train Acc = 0.9351, Train F1 = 0.9026 | Val Loss = 0.0076, Val Acc = 0.9407, Val F1 = 0.9123
# Epoch 113: Train Loss = 0.0080, Train Acc = 0.9322, Train F1 = 0.8990 | Val Loss = 0.0080, Val Acc = 0.9353, Val F1 = 0.9051
# Epoch 114: Train Loss = 0.0078, Train Acc = 0.9387, Train F1 = 0.9085 | Val Loss = 0.0083, Val Acc = 0.9316, Val F1 = 0.9028
# Epoch 115: Train Loss = 0.0079, Train Acc = 0.9356, Train F1 = 0.9040 | Val Loss = 0.0077, Val Acc = 0.9395, Val F1 = 0.9107
# Epoch 116: Train Loss = 0.0078, Train Acc = 0.9345, Train F1 = 0.9023 | Val Loss = 0.0079, Val Acc = 0.9328, Val F1 = 0.8962
# Epoch 117: Train Loss = 0.0079, Train Acc = 0.9357, Train F1 = 0.9043 | Val Loss = 0.0076, Val Acc = 0.9347, Val F1 = 0.8994
# Epoch 118: Train Loss = 0.0080, Train Acc = 0.9344, Train F1 = 0.9024 | Val Loss = 0.0075, Val Acc = 0.9389, Val F1 = 0.9095
# Epoch 119: Train Loss = 0.0079, Train Acc = 0.9359, Train F1 = 0.9045 | Val Loss = 0.0085, Val Acc = 0.9280, Val F1 = 0.8854
# Epoch 120: Train Loss = 0.0079, Train Acc = 0.9347, Train F1 = 0.9023 | Val Loss = 0.0085, Val Acc = 0.9280, Val F1 = 0.8854
# Epoch 121: Train Loss = 0.0079, Train Acc = 0.9356, Train F1 = 0.9039 | Val Loss = 0.0083, Val Acc = 0.9280, Val F1 = 0.8867
# Epoch 122: Train Loss = 0.0077, Train Acc = 0.9380, Train F1 = 0.9079 | Val Loss = 0.0074, Val Acc = 0.9395, Val F1 = 0.9114
# Epoch 123: Train Loss = 0.0082, Train Acc = 0.9321, Train F1 = 0.8987 | Val Loss = 0.0075, Val Acc = 0.9359, Val F1 = 0.9019
# Epoch 124: Train Loss = 0.0078, Train Acc = 0.9381, Train F1 = 0.9079 | Val Loss = 0.0076, Val Acc = 0.9401, Val F1 = 0.9139
# Epoch 125: Train Loss = 0.0075, Train Acc = 0.9381, Train F1 = 0.9076 | Val Loss = 0.0083, Val Acc = 0.9365, Val F1 = 0.9112
# Epoch 126: Train Loss = 0.0080, Train Acc = 0.9340, Train F1 = 0.9015 | Val Loss = 0.0077, Val Acc = 0.9371, Val F1 = 0.9031
# Epoch 127: Train Loss = 0.0076, Train Acc = 0.9384, Train F1 = 0.9084 | Val Loss = 0.0073, Val Acc = 0.9425, Val F1 = 0.9159
# Epoch 128: Train Loss = 0.0074, Train Acc = 0.9395, Train F1 = 0.9097 | Val Loss = 0.0081, Val Acc = 0.9347, Val F1 = 0.9076
# Epoch 129: Train Loss = 0.0077, Train Acc = 0.9344, Train F1 = 0.9022 | Val Loss = 0.0084, Val Acc = 0.9322, Val F1 = 0.9048
# Epoch 130: Train Loss = 0.0075, Train Acc = 0.9369, Train F1 = 0.9060 | Val Loss = 0.0077, Val Acc = 0.9335, Val F1 = 0.8966
# Epoch 131: Train Loss = 0.0075, Train Acc = 0.9380, Train F1 = 0.9075 | Val Loss = 0.0073, Val Acc = 0.9377, Val F1 = 0.9060
# Epoch 132: Train Loss = 0.0075, Train Acc = 0.9378, Train F1 = 0.9077 | Val Loss = 0.0085, Val Acc = 0.9310, Val F1 = 0.8908
# Epoch 133: Train Loss = 0.0076, Train Acc = 0.9375, Train F1 = 0.9068 | Val Loss = 0.0071, Val Acc = 0.9425, Val F1 = 0.9154
# Epoch 134: Train Loss = 0.0075, Train Acc = 0.9374, Train F1 = 0.9066 | Val Loss = 0.0075, Val Acc = 0.9419, Val F1 = 0.9167
# Epoch 135: Train Loss = 0.0077, Train Acc = 0.9366, Train F1 = 0.9059 | Val Loss = 0.0076, Val Acc = 0.9341, Val F1 = 0.8983
# Epoch 136: Train Loss = 0.0077, Train Acc = 0.9368, Train F1 = 0.9057 | Val Loss = 0.0071, Val Acc = 0.9425, Val F1 = 0.9144
# Epoch 137: Train Loss = 0.0075, Train Acc = 0.9403, Train F1 = 0.9113 | Val Loss = 0.0073, Val Acc = 0.9371, Val F1 = 0.9035
# Epoch 138: Train Loss = 0.0074, Train Acc = 0.9401, Train F1 = 0.9107 | Val Loss = 0.0073, Val Acc = 0.9377, Val F1 = 0.9106
# Epoch 139: Train Loss = 0.0078, Train Acc = 0.9372, Train F1 = 0.9067 | Val Loss = 0.0080, Val Acc = 0.9359, Val F1 = 0.8999
# Epoch 140: Train Loss = 0.0074, Train Acc = 0.9401, Train F1 = 0.9117 | Val Loss = 0.0070, Val Acc = 0.9456, Val F1 = 0.9190
# Epoch 141: Train Loss = 0.0073, Train Acc = 0.9374, Train F1 = 0.9066 | Val Loss = 0.0095, Val Acc = 0.9250, Val F1 = 0.8990
# Epoch 142: Train Loss = 0.0073, Train Acc = 0.9398, Train F1 = 0.9107 | Val Loss = 0.0074, Val Acc = 0.9383, Val F1 = 0.9105
# Epoch 143: Train Loss = 0.0077, Train Acc = 0.9386, Train F1 = 0.9092 | Val Loss = 0.0094, Val Acc = 0.9165, Val F1 = 0.8634
# Epoch 144: Train Loss = 0.0072, Train Acc = 0.9415, Train F1 = 0.9127 | Val Loss = 0.0070, Val Acc = 0.9425, Val F1 = 0.9147
# Epoch 145: Train Loss = 0.0075, Train Acc = 0.9363, Train F1 = 0.9053 | Val Loss = 0.0081, Val Acc = 0.9365, Val F1 = 0.9007
# Epoch 146: Train Loss = 0.0076, Train Acc = 0.9387, Train F1 = 0.9094 | Val Loss = 0.0072, Val Acc = 0.9425, Val F1 = 0.9140
# Epoch 147: Train Loss = 0.0078, Train Acc = 0.9356, Train F1 = 0.9038 | Val Loss = 0.0079, Val Acc = 0.9371, Val F1 = 0.9116
# Epoch 148: Train Loss = 0.0080, Train Acc = 0.9365, Train F1 = 0.9057 | Val Loss = 0.0074, Val Acc = 0.9389, Val F1 = 0.9118
# Epoch 149: Train Loss = 0.0076, Train Acc = 0.9395, Train F1 = 0.9100 | Val Loss = 0.0069, Val Acc = 0.9437, Val F1 = 0.9160
# Epoch 150: Train Loss = 0.0074, Train Acc = 0.9407, Train F1 = 0.9117 | Val Loss = 0.0072, Val Acc = 0.9431, Val F1 = 0.9164
# Epoch 151: Train Loss = 0.0074, Train Acc = 0.9404, Train F1 = 0.9115 | Val Loss = 0.0075, Val Acc = 0.9383, Val F1 = 0.9045
# Epoch 152: Train Loss = 0.0072, Train Acc = 0.9413, Train F1 = 0.9128 | Val Loss = 0.0075, Val Acc = 0.9443, Val F1 = 0.9213
# Epoch 153: Train Loss = 0.0070, Train Acc = 0.9415, Train F1 = 0.9135 | Val Loss = 0.0068, Val Acc = 0.9468, Val F1 = 0.9203
# Epoch 154: Train Loss = 0.0074, Train Acc = 0.9386, Train F1 = 0.9088 | Val Loss = 0.0079, Val Acc = 0.9310, Val F1 = 0.8914
# Epoch 155: Train Loss = 0.0071, Train Acc = 0.9410, Train F1 = 0.9125 | Val Loss = 0.0073, Val Acc = 0.9377, Val F1 = 0.9033
# Epoch 156: Train Loss = 0.0071, Train Acc = 0.9442, Train F1 = 0.9170 | Val Loss = 0.0077, Val Acc = 0.9425, Val F1 = 0.9197
# Epoch 157: Train Loss = 0.0074, Train Acc = 0.9378, Train F1 = 0.9079 | Val Loss = 0.0072, Val Acc = 0.9437, Val F1 = 0.9196
# Epoch 158: Train Loss = 0.0073, Train Acc = 0.9398, Train F1 = 0.9105 | Val Loss = 0.0067, Val Acc = 0.9468, Val F1 = 0.9225
# Epoch 159: Train Loss = 0.0069, Train Acc = 0.9446, Train F1 = 0.9176 | Val Loss = 0.0083, Val Acc = 0.9353, Val F1 = 0.9112
# Epoch 160: Train Loss = 0.0074, Train Acc = 0.9383, Train F1 = 0.9084 | Val Loss = 0.0070, Val Acc = 0.9395, Val F1 = 0.9133
# Epoch 161: Train Loss = 0.0068, Train Acc = 0.9442, Train F1 = 0.9175 | Val Loss = 0.0069, Val Acc = 0.9437, Val F1 = 0.9177
# Epoch 162: Train Loss = 0.0069, Train Acc = 0.9427, Train F1 = 0.9150 | Val Loss = 0.0067, Val Acc = 0.9449, Val F1 = 0.9191
# Epoch 163: Train Loss = 0.0074, Train Acc = 0.9421, Train F1 = 0.9139 | Val Loss = 0.0067, Val Acc = 0.9456, Val F1 = 0.9198
# Epoch 164: Train Loss = 0.0071, Train Acc = 0.9416, Train F1 = 0.9133 | Val Loss = 0.0066, Val Acc = 0.9480, Val F1 = 0.9227
# Epoch 165: Train Loss = 0.0070, Train Acc = 0.9436, Train F1 = 0.9164 | Val Loss = 0.0069, Val Acc = 0.9449, Val F1 = 0.9193
# Epoch 166: Train Loss = 0.0071, Train Acc = 0.9430, Train F1 = 0.9155 | Val Loss = 0.0075, Val Acc = 0.9401, Val F1 = 0.9074
# Epoch 167: Train Loss = 0.0069, Train Acc = 0.9436, Train F1 = 0.9164 | Val Loss = 0.0066, Val Acc = 0.9468, Val F1 = 0.9211
# Epoch 168: Train Loss = 0.0069, Train Acc = 0.9433, Train F1 = 0.9159 | Val Loss = 0.0081, Val Acc = 0.9298, Val F1 = 0.8889
# Epoch 169: Train Loss = 0.0074, Train Acc = 0.9396, Train F1 = 0.9108 | Val Loss = 0.0066, Val Acc = 0.9504, Val F1 = 0.9279
# Epoch 170: Train Loss = 0.0067, Train Acc = 0.9457, Train F1 = 0.9194 | Val Loss = 0.0069, Val Acc = 0.9431, Val F1 = 0.9150
# Epoch 171: Train Loss = 0.0074, Train Acc = 0.9383, Train F1 = 0.9089 | Val Loss = 0.0068, Val Acc = 0.9468, Val F1 = 0.9209
# Epoch 172: Train Loss = 0.0069, Train Acc = 0.9440, Train F1 = 0.9168 | Val Loss = 0.0070, Val Acc = 0.9449, Val F1 = 0.9220
# Epoch 173: Train Loss = 0.0071, Train Acc = 0.9442, Train F1 = 0.9175 | Val Loss = 0.0074, Val Acc = 0.9443, Val F1 = 0.9221
# Epoch 174: Train Loss = 0.0067, Train Acc = 0.9469, Train F1 = 0.9217 | Val Loss = 0.0068, Val Acc = 0.9468, Val F1 = 0.9196
# Epoch 175: Train Loss = 0.0067, Train Acc = 0.9460, Train F1 = 0.9201 | Val Loss = 0.0066, Val Acc = 0.9504, Val F1 = 0.9252
# Epoch 176: Train Loss = 0.0066, Train Acc = 0.9469, Train F1 = 0.9216 | Val Loss = 0.0065, Val Acc = 0.9498, Val F1 = 0.9265
# Epoch 177: Train Loss = 0.0065, Train Acc = 0.9477, Train F1 = 0.9227 | Val Loss = 0.0068, Val Acc = 0.9401, Val F1 = 0.9087
# Epoch 178: Train Loss = 0.0067, Train Acc = 0.9440, Train F1 = 0.9171 | Val Loss = 0.0068, Val Acc = 0.9401, Val F1 = 0.9142
# Epoch 179: Train Loss = 0.0067, Train Acc = 0.9452, Train F1 = 0.9190 | Val Loss = 0.0080, Val Acc = 0.9353, Val F1 = 0.8984
# Epoch 180: Train Loss = 0.0069, Train Acc = 0.9448, Train F1 = 0.9185 | Val Loss = 0.0068, Val Acc = 0.9413, Val F1 = 0.9155
# Epoch 181: Train Loss = 0.0065, Train Acc = 0.9474, Train F1 = 0.9221 | Val Loss = 0.0069, Val Acc = 0.9389, Val F1 = 0.9090
# Epoch 182: Train Loss = 0.0068, Train Acc = 0.9460, Train F1 = 0.9199 | Val Loss = 0.0070, Val Acc = 0.9407, Val F1 = 0.9161
# Epoch 183: Train Loss = 0.0066, Train Acc = 0.9484, Train F1 = 0.9238 | Val Loss = 0.0064, Val Acc = 0.9468, Val F1 = 0.9208
# Epoch 184: Train Loss = 0.0071, Train Acc = 0.9407, Train F1 = 0.9118 | Val Loss = 0.0067, Val Acc = 0.9468, Val F1 = 0.9240
# Epoch 185: Train Loss = 0.0066, Train Acc = 0.9468, Train F1 = 0.9214 | Val Loss = 0.0064, Val Acc = 0.9443, Val F1 = 0.9194
# Epoch 186: Train Loss = 0.0066, Train Acc = 0.9474, Train F1 = 0.9223 | Val Loss = 0.0070, Val Acc = 0.9419, Val F1 = 0.9105
# Epoch 187: Train Loss = 0.0065, Train Acc = 0.9457, Train F1 = 0.9194 | Val Loss = 0.0072, Val Acc = 0.9449, Val F1 = 0.9223
# Epoch 188: Train Loss = 0.0066, Train Acc = 0.9469, Train F1 = 0.9217 | Val Loss = 0.0064, Val Acc = 0.9437, Val F1 = 0.9188
# Epoch 189: Train Loss = 0.0065, Train Acc = 0.9475, Train F1 = 0.9225 | Val Loss = 0.0065, Val Acc = 0.9468, Val F1 = 0.9237
# Epoch 190: Train Loss = 0.0065, Train Acc = 0.9466, Train F1 = 0.9213 | Val Loss = 0.0063, Val Acc = 0.9443, Val F1 = 0.9183
# Epoch 191: Train Loss = 0.0066, Train Acc = 0.9468, Train F1 = 0.9214 | Val Loss = 0.0081, Val Acc = 0.9328, Val F1 = 0.8962
# Epoch 192: Train Loss = 0.0069, Train Acc = 0.9430, Train F1 = 0.9159 | Val Loss = 0.0066, Val Acc = 0.9437, Val F1 = 0.9190
# Epoch 193: Train Loss = 0.0069, Train Acc = 0.9455, Train F1 = 0.9197 | Val Loss = 0.0064, Val Acc = 0.9516, Val F1 = 0.9274
# Epoch 194: Train Loss = 0.0066, Train Acc = 0.9455, Train F1 = 0.9195 | Val Loss = 0.0065, Val Acc = 0.9498, Val F1 = 0.9242
# Epoch 195: Train Loss = 0.0066, Train Acc = 0.9442, Train F1 = 0.9175 | Val Loss = 0.0064, Val Acc = 0.9443, Val F1 = 0.9196
# Epoch 196: Train Loss = 0.0063, Train Acc = 0.9499, Train F1 = 0.9261 | Val Loss = 0.0066, Val Acc = 0.9474, Val F1 = 0.9202
# Epoch 197: Train Loss = 0.0065, Train Acc = 0.9462, Train F1 = 0.9206 | Val Loss = 0.0083, Val Acc = 0.9383, Val F1 = 0.9152
# Epoch 198: Train Loss = 0.0070, Train Acc = 0.9440, Train F1 = 0.9170 | Val Loss = 0.0088, Val Acc = 0.9310, Val F1 = 0.9063
# Epoch 199: Train Loss = 0.0069, Train Acc = 0.9451, Train F1 = 0.9194 | Val Loss = 0.0066, Val Acc = 0.9474, Val F1 = 0.9209

# %%
from sklearn.metrics import f1_score
import torch
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(filter(lambda p: p.requires_grad, model.parameters()), lr=1e-3)
def evaluate_f1_macro(model, dataloader, criterion, device):
    # --- Validation ---
    model.eval()
    val_loss = 0.0
    all_val_preds = []
    all_val_labels = []

    with torch.no_grad():
        for x_val, y_val in dataloader:
            x_val, y_val = x_val.to(device), y_val.to(device)
            outputs = model(x_val)
            loss = criterion(outputs, y_val)
            val_loss += loss.item()

            preds = torch.argmax(outputs, dim=1)
            all_val_preds.extend(preds.cpu().numpy())
            all_val_labels.extend(y_val.cpu().numpy())

    avg_val_loss = val_loss / len(val_loader)
    val_accuracy = accuracy_score(all_val_labels, all_val_preds)
    val_f1_macro = f1_score(all_val_labels, all_val_preds, average='macro')
    val_losses.append(avg_val_loss)
    
    return avg_val_loss, val_f1_macro

val_loss, val_f1 = evaluate_f1_macro(model, test_loader_wesad, criterion, device)
print(f"Validation Loss: {val_loss:.4f}, Macro F1 Score: {val_f1:.4f}")
# Out:
# Validation Loss: 0.0196, Macro F1 Score: 0.3286
